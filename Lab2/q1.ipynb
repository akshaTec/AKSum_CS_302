# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cin= 0
v= 10**12
f= 5*10**8

# %%
a= f*cin/v
b= f/v
c_o= 10

# %%
def c_dot(a,b,c):
    return a - b*c

# %%
k= -(1/b*np.log(b*c_o -a))

# %%
def fc(a,b,k,t):
    return (a+ np.exp(-b*(t+k)))/(b)

# %%
x= np.linspace(0,10**4,1000)
y= fc(a,b,k,x)

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.xlabel("Time (s)") 
plt.ylabel("Concentration (M)")
plt.savefig("q1_2.png")
plt.show()

# %%
def time_for_some_amount(c_o,b,a,k):
    return (-1/b)*np.log(c_o*b-a) - k

# %%
print(time_for_some_amount(c_o/2,b,a,k))
# Out:
# 1386.2943611198916
