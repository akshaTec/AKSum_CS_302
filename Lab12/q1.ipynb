# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('price.csv', header=None)
data.head()
# Out:
#    0  1           2
# 0  1  1  939.549988
# 1  2  2  927.049988
# 2  3  3  931.650024
# 3  4  4  927.799988
# 4  5  5  928.799988

# %%
#plot the data with fine size and price
plt.figure(figsize=(10,8))
plt.plot(data[0], data[2], color='green')
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Size vs Price')
plt.show()

#initialize variabl
