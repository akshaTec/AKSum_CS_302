# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Define the parameters
k = 1.2
l = 1.5
h = 0
g = 0
alpha = 1.8
beta = 1.7

# time step
dt = 0.01
t_max = 10

# store the solution
t = np.arange(0, t_max + dt, dt)
x = np.zeros_like(t)
y = np.zeros_like(t)

# initial conditions
x[0] = 0.8
y[0] = 0.2

# Euler integration
for i in range(1, len(t)):
    x[i] = x[i - 1] + dt * (k * y[i - 1] + g - alpha * x[i - 1])
    y[i] = y[i - 1] + dt * (l * x[i - 1] + h - beta * y[i - 1])

plt.figure(figsize=(10, 8))
plt.plot(t, x, label=r"$x(t)$")
plt.plot(t, y, label=r"$y(t)$")

# plt.yscale('log')  # Change Y-axis to log scale
plt.title("Mutual Disarmament without grievenances")
plt.xlabel("t")
plt.ylabel("x(t), y(t)")
plt.legend()
plt.grid()
plt.savefig("A1_2.png")

plt.show()

# %%
plt.figure(figsize=(10, 8))

# Plot y vs x
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Mutual Disarmament without grievenances")
plt.grid()
plt.savefig("A2.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Changes in the parameters
k = 1.2
l = 1.5
h = 0.7
g = 0.5
alpha = 1.8
beta = 1.7


# time step
dt = 0.01
t_max = 10

# store the solution
t = np.arange(0, t_max + dt, dt)
x = np.zeros_like(t)
y = np.zeros_like(t)

# initial conditions
x[0] = 0
y[0] = 0

# Euler integration
for i in range(1, len(t)):
    x[i] = x[i - 1] + dt * (k * y[i - 1] + g - alpha * x[i - 1])
    y[i] = y[i - 1] + dt * (l * x[i - 1] + h - beta * y[i - 1])

plt.figure(figsize=(10, 8))
plt.plot(t, x, label=r"$x(t)$")
plt.plot(t, y, label=r"$y(t)$")

plt.yscale('log')  # Change Y-axis to log scale
plt.title("Mutual Disarmament with grievenances")
plt.xlabel("t")
plt.ylabel("x(t), y(t)")
plt.legend()
plt.grid()
plt.savefig("B1.png")

plt.show()

# %%
plt.figure(figsize=(10, 8))

# Plot y vs x
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.title("Mutual Disarmament with grievenances")
plt.savefig("B2.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Changes in the parameters
k = 1.2
l = 1.5
h = 0.7
g = 0.5
alpha = 1.8
beta = 1.7


# time step
dt = 0.01
t_max = 10

# store the solution
t = np.arange(0, t_max + dt, dt)
x = np.zeros_like(t)
y = np.zeros_like(t)

# initial conditions
x[0] = 0.5
y[0] = 0

# Euler integration
for i in range(1, len(t)):
    x[i] = x[i - 1] + dt * (k * y[i - 1] + g - alpha * x[i - 1])
    y[i] = y[i - 1] + dt * (l * x[i - 1] + h - beta * y[i - 1])

plt.figure(figsize=(10, 8))
# plt.plot(t, x, label=r"$x(t)$")
plt.plot(t, y, label=r"$y(t)$")

plt.yscale('log')  # Change Y-axis to log scale

plt.xlabel("t")
plt.ylabel("x(t), y(t)")
plt.title("Unilateral Disarmament")
plt.legend()
plt.grid()
plt.savefig("C1.png")

plt.show()

# %%
plt.figure(figsize=(10, 8))

# Plot y vs x
plt.plot(x, y)
plt.xlabel("x")
plt.title("Unilateral Disarmament")
plt.ylabel("y")
plt.grid()
plt.savefig("C2.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Changes in the parameters
k = 1.2
l = 1.5
h = 0
g = 0
alpha = 0
beta = 0


# time step
dt = 0.01
t_max = 2

# store the solution
t = np.arange(0, t_max + dt, dt)
x = np.zeros_like(t)
y = np.zeros_like(t)

# initial conditions
x[0] = 0.8
y[0] = 0.3

# Euler integration
for i in range(1, len(t)):
    x[i] = x[i - 1] + dt * (k * y[i - 1] + g - alpha * x[i - 1])
    y[i] = y[i - 1] + dt * (l * x[i - 1] + h - beta * y[i - 1])

plt.figure(figsize=(10, 8))
plt.plot(t, x, label=r"$x(t)$")
plt.plot(t, y, label=r"$y(t)$")

# plt.yscale('log')  # Change Y-axis to log scale

plt.xlabel("t")
plt.ylabel("x(t), y(t)")
plt.legend()
plt.title("Arm's Race")
# plt.grid()
plt.savefig("D1.png")

plt.show()

# %%
# Changes in the parameters
k = 1.2
l = 1.5
h = 0
g = 0
alpha = 0
beta = 0


# time step
dt = 0.01
t_max = 2

# store the solution
t = np.arange(0, t_max + dt, dt)
x = np.zeros_like(t)
y = np.zeros_like(t)

# initial conditions
x[0] = 0.8
y[0] = 0.3

# Euler integration
for i in range(1, len(t)):
    x[i] = x[i - 1] + dt * (k * y[i - 1] + g - alpha * x[i - 1])
    y[i] = y[i - 1] + dt * (l * x[i - 1] + h - beta * y[i - 1])

plt.figure(figsize=(10, 8))
plt.plot(t, x, label=r"$x(t)$")
plt.plot(t, y, label=r"$y(t)$")

plt.yscale('log')  # Change Y-axis to log scale

plt.xlabel("t")
plt.ylabel("x(t), y(t)")
plt.legend()
# plt.grid()
plt.title("Arm's Race")
plt.savefig("D2.png")

plt.show()

# %%
plt.figure(figsize=(10, 8))

# Plot y vs x
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Arm's Race")
# plt.grid()
plt.savefig("D3.png")

plt.show()
