# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read traffic_time.csv into a DataFrame
df = pd.read_csv('traffic_time.csv')
df
# Out:
#      58.183701  -11   41.740002
# 0    46.897999  -10   32.619999
# 1    39.204102   -9   31.900000
# 2    43.550999   -8   57.000000
# 3    64.693901   -7  144.759990
# 4   142.408200   -6  435.720000
# 5   237.775500   -5  691.780030
# 6   349.081600   -4  677.000000
# 7   358.000000   -3  486.859990
# 8   388.367310   -2  447.179990
# 9   395.428590   -1  411.579990
# 10  403.061190    0  380.660000
# 11  420.938810    1  402.859990
# 12  452.204100    2  413.660000
# 13  507.510190    3  428.299990
# 14  638.734680    4  451.060000
# 15  775.959230    5  454.880000
# 16  746.101990    6  425.820010
# 17  497.959200    7  308.780000
# 18  300.183690    8  202.880000
# 19  234.163300    9  174.500000
# 20  194.571400   10  141.179990
# 21  125.102000   11   98.680000
# 22   81.367302   12   60.480000

# %% [markdown]
# ### The first column gives the average volume of traffic flowing towards the east.
# ### The second column gives the hour of the day, with the 0 hour being set at midday, 12 pm. So all forenoon hours are negative.
# ### The third column gives the average volume of the traffic flowing towards the west.

# %%
plt.figure(figsize=(10,8))
plt.xlabel('time')
plt.ylabel('traffic')
plt.plot(df.iloc[:, 1],df.iloc[:, 0], label='to the east')
plt.plot(df.iloc[:, 1],df.iloc[:, 2], label='to the west')

plt.legend()
# plt.savefig("q1_1.png")
plt.show()

# %% [markdown]
# # with A=44.0,µ = 8.53,λ = 0.19and β = −0.09.

# %%
A = 44.0
mu = 8.53
lam = 0.19
beta = -0.09

def N(t):
  return A * np.exp(-(lam*t - beta)**2) * (mu + t**2)

t_vals = np.linspace(-12, 12, 1000)
N_vals = N(t_vals)

plt.figure(figsize=(10,8))
plt.xlabel('time')
plt.ylabel('traffic')
# plt.plot(df.iloc[:, 1],df.iloc[:, 0], label='to the east')
plt.plot(df.iloc[:, 1],df.iloc[:, 2], label='Analytical model')



plt.plot(t_vals, N_vals, label="Real data")
plt.xlabel('t')
plt.ylabel('N(t)')
plt.title('Plot of N(t) vs t')
# plt.xlim(-12, 12)
# plt.ylim(0, 50)
plt.legend()
plt.savefig("q1_1.png")
plt.show()

# %%
A = 44.1
mu = 10.5
lam = 0.22
beta = 0.24

def N(t):
  return A * np.exp(-(lam*t - beta)**2) * (mu + t**2)

t_vals = np.linspace(-12, 12, 1000)
N_vals = N(t_vals)

plt.figure(figsize=(10,8))
plt.xlabel('time')
plt.ylabel('traffic')
plt.plot(df.iloc[:, 1],df.iloc[:, 0], label='Analytical model')
# plt.plot(df.iloc[:, 1],df.iloc[:, 2], label='to the west')



plt.plot(t_vals, N_vals, label="Real data")
plt.xlabel('t')
plt.ylabel('N(t)')
plt.title('Plot of N(t) vs t')
# plt.xlim(-12, 12)
# plt.ylim(0, 50)
plt.legend()
plt.savefig('q1_2.png')
plt.show()
