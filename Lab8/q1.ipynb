# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q1

# %%
a0= 66454
j0=18274

a= 0.0106
j= 0.0544

# %%
k= a0*a*a - j0*j*j

print(k)
# Out:
# -46.61257319999999

# %%
print("Japan Wins")
# Out:
# Japan Wins

# %% [markdown]
# ## Q2
